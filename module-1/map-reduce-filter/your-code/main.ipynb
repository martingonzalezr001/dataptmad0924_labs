# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources in the README.md file
# - Happy learning!

# %%
# Import reduce from functools, numpy and pandas
import re
import functools
import numpy as np
import pandas as pd

# %% [markdown]
# # Challenge 1 - Mapping
#
# #### We will use the map function to clean up words in a book.
#
# In the following cell, we will read a text file containing the book The Prophet by Khalil Gibran.

# %%
# Run this code:

location = '../data/58585-0.txt'
with open(location, 'r', encoding="utf8") as f:
    prophet = f.read().split(' ')

# %% [markdown]
# #### Let's remove the first 568 words since they contain information about the book but are not part of the book itself.
#
# Do this by removing from `prophet` elements 0 through 567 of the list (you can also do this by keeping elements 568 through the last element).

# %%
# your code here
#print(prophet)
new_book = enumerate(prophet,568)
list_book = (list(new_book))

# %% [markdown]
# If you look through the words, you will find that many words have a reference attached to them. For example, let's look at words 1 through 10.

# %%
# your code here
print(list_book)
# Out:
# [(568, '\ufeffThe'), (569, 'Project'), (570, 'Gutenberg'), (571, 'EBook'), (572, 'of'), (573, 'The'), (574, 'Prophet,'), (575, 'by'), (576, 'Kahlil'), (577, 'Gibran\n\nThis'), (578, 'eBook'), (579, 'is'), (580, 'for'), (581, 'the'), (582, 'use'), (583, 'of'), (584, 'anyone'), (585, 'anywhere'), (586, 'in'), (587, 'the'), (588, 'United'), (589, 'States'), (590, 'and\nmost'), (591, 'other'), (592, 'parts'), (593, 'of'), (594, 'the'), (595, 'world'), (596, 'at'), (597, 'no'), (598, 'cost'), (599, 'and'), (600, 'with'), (601, 'almost'), (602, 'no'), (603, 'restrictions\nwhatsoever.'), (604, ''), (605, 'You'), (606, 'may'), (607, 'copy'), (608, 'it,'), (609, 'give'), (610, 'it'), (611, 'away'), (612, 'or'), (613, 're-use'), (614, 'it'), (615, 'under'), (616, 'the'), (617, 'terms\nof'), (618, 'the'), (619, 'Project'), (620, 'Gutenberg'), (621, 'License'), (622, 'included'), (623, 'with'), (624, 'this'), (625, 'eBook'), (626, 'or'), (627, 'online'), (628, 'at\nwww.gutenberg.org.'), (629, ''
# ...

# %%
for x in range(1,10):
    print(list_book[x])
# Out:
# (569, 'Project')
# (570, 'Gutenberg')
# (571, 'EBook')
# (572, 'of')
# (573, 'The')
# (574, 'Prophet,')
# (575, 'by')
# (576, 'Kahlil')
# (577, 'Gibran\n\nThis')

# %% [markdown]
# #### The next step is to create a function that will remove references.
#
# We will do this by splitting the string on the `{` character and keeping only the part before this character. Write your function below.

# %%
def reference(x):
    '''
    Input: A string
    Output: The string with references removed
    
    Example:
    Input: 'the{7}'
    Output: 'the'
    '''

    
    x = re.sub(r'\{\d+\}',"", x) #This line replaces the '{number}' to ''
    print("Character without references: " + str(x))
    return x
    
    # your code here

# %%
reference("{101}Why")
# Out:
# Character without references: Why
# 'Why'

# %% [markdown]
# Now that we have our function, use the `map()` function to apply this function to our book, The Prophet. Return the resulting list to a new list called `prophet_reference`.

# %%
#print(list_book)
prophet_reference = []
for x in list_book:
    x = reference(x[1])
    prophet_reference.append(x)

print(prophet_reference)
print(type(prophet_reference))
# Out:
# Character without references: ﻿The
# Character without references: Project
# Character without references: Gutenberg
# Character without references: EBook
# Character without references: of
# Character without references: The
# Character without references: Prophet,
# Character without references: by
# Character without references: Kahlil
# Character without references: Gibran
#
# This
# Character without references: eBook
# Character without references: is
# Character without references: for
# Character without references: the
# Character without references: use
# Character without references: of
# Character without references: anyone
# Character without references: anywhere
# Character without references: in
# Character without references: the
# Character without references: United
# Character without references: States
# Character without references: and
# most
# Character without references: other
# Character without references: parts
# Character without references: of
# ...

# %% [markdown]
# Another thing you may have noticed is that some words contain a line break. Let's write a function to split those words. Our function will return the string split on the character `\n`. Write your function in the cell below.

# %%
def line_break(x):
    '''
    Input: A string
    Output: A list of strings split on the line break (\n) character
        
    Example:
    Input: 'the\nbeloved'
    Output: ['the', 'beloved']

    
    '''
    x = x.split("\n")
    return x
    
    # your code here

# %%
line_break('the\nharbour,')
# Out:
# ['the', 'harbour,']

# %% [markdown]
# Apply the `line_break` function to the `prophet_reference` list. Name the new list `prophet_line`.

# %%
# your code here
#print(list_book)
#print(prophet_reference)
prophet_line = []
for x in prophet_reference:
    x = line_break(x)
    prophet_line.append(x)

print(prophet_line)
# Out:
# [['\ufeffThe'], ['Project'], ['Gutenberg'], ['EBook'], ['of'], ['The'], ['Prophet,'], ['by'], ['Kahlil'], ['Gibran', '', 'This'], ['eBook'], ['is'], ['for'], ['the'], ['use'], ['of'], ['anyone'], ['anywhere'], ['in'], ['the'], ['United'], ['States'], ['and', 'most'], ['other'], ['parts'], ['of'], ['the'], ['world'], ['at'], ['no'], ['cost'], ['and'], ['with'], ['almost'], ['no'], ['restrictions', 'whatsoever.'], [''], ['You'], ['may'], ['copy'], ['it,'], ['give'], ['it'], ['away'], ['or'], ['re-use'], ['it'], ['under'], ['the'], ['terms', 'of'], ['the'], ['Project'], ['Gutenberg'], ['License'], ['included'], ['with'], ['this'], ['eBook'], ['or'], ['online'], ['at', 'www.gutenberg.org.'], [''], ['If'], ['you'], ['are'], ['not'], ['located'], ['in'], ['the'], ['United'], ['States,'], ["you'll", 'have'], ['to'], ['check'], ['the'], ['laws'], ['of'], ['the'], ['country'], ['where'], ['you'], ['are'], ['located'], ['before'], ['using', 'this'], ['ebook.', '', '', '', 'Title:'], ['The'], [
# ...

# %% [markdown]
# If you look at the elements of `prophet_line`, you will see that the function returned lists and not strings. Our list is now a list of lists. Flatten the list using list comprehension. Assign this new list to `prophet_flat`.

# %%
# your code here

#Normal way
prophet_flat = []
for x in prophet_line:
    if len(x) > 1:
        for y in x:
            prophet_flat.append(y)

#prophet_flat = [new_x for x in prophet_line if x < 1 ]



print(prophet_flat)
# Out:
# ['Gibran', '', 'This', 'and', 'most', 'restrictions', 'whatsoever.', 'terms', 'of', 'at', 'www.gutenberg.org.', "you'll", 'have', 'using', 'this', 'ebook.', '', '', '', 'Title:', 'Prophet', '', 'Author:', 'Gibran', '', 'Release', '#58585]', 'Last', '2018', '', '', 'Language:', 'English', '', 'Character', 'UTF-8', '', '***', '***', '', '', '', '', 'Produced', 'generously', 'provided', 'Archive', '', '', "Transcriber's", 'this', 'utf-8', 'unencumbered', 'with', '58585-8.txt.', '', '', '', '', '', '', '', 'THE', 'PROPHET', '', 'By', 'Gibran', '', 'New', 'Knopf', '', '1923', '', '_The', 'Volume', 'Are', 'By', 'The', 'Author_', '', '', '“His', 'reservoir', 'of', 'have', 'been', 'the', 'majesty', 'with', 'which', 'own?”', '', '--Claude', 'Bragdon', '', '', 'THE', 'GIBRAN', '', 'The', '1919', 'The', '1923', 'Sand', 'of', 'Man.', 'The', 'Wanderer.', 'Prophet', '1933', 'the', 'Valley.', '1948', '', '', '', '', 'CONTENTS', '', '', 'Ship.......7', '', 'Love.....................15', '', 'Marriag
# ...

# %%
# List comprehension way
print(prophet_line)
prophet_flat = [y for x in prophet_line if len(x) > 1 for y in x]
#print(prophet_flat)
# Out:
# [['\ufeffThe'], ['Project'], ['Gutenberg'], ['EBook'], ['of'], ['The'], ['Prophet,'], ['by'], ['Kahlil'], ['Gibran', '', 'This'], ['eBook'], ['is'], ['for'], ['the'], ['use'], ['of'], ['anyone'], ['anywhere'], ['in'], ['the'], ['United'], ['States'], ['and', 'most'], ['other'], ['parts'], ['of'], ['the'], ['world'], ['at'], ['no'], ['cost'], ['and'], ['with'], ['almost'], ['no'], ['restrictions', 'whatsoever.'], [''], ['You'], ['may'], ['copy'], ['it,'], ['give'], ['it'], ['away'], ['or'], ['re-use'], ['it'], ['under'], ['the'], ['terms', 'of'], ['the'], ['Project'], ['Gutenberg'], ['License'], ['included'], ['with'], ['this'], ['eBook'], ['or'], ['online'], ['at', 'www.gutenberg.org.'], [''], ['If'], ['you'], ['are'], ['not'], ['located'], ['in'], ['the'], ['United'], ['States,'], ["you'll", 'have'], ['to'], ['check'], ['the'], ['laws'], ['of'], ['the'], ['country'], ['where'], ['you'], ['are'], ['located'], ['before'], ['using', 'this'], ['ebook.', '', '', '', 'Title:'], ['The'], [
# ...

# %% [markdown]
# # Challenge 2 - Filtering
#
# When printing out a few words from the book, we see that there are words that we may not want to keep if we choose to analyze the corpus of text. Below is a list of words that we would like to get rid of. Create a function that will return false if it contains a word from the list of words specified and true otherwise.

# %%
def word_filter(x):
    '''
    Input: A string
    Output: True if the word is not in the specified list 
    and False if the word is in the list.
        
    Example:
    word list = ['and', 'the']
    Input: 'and'
    Output: False
    
    Input: 'John'
    Output: True
    '''
    words_eq = []

    word_list = ['and', 'the', 'a', 'an']
    for y in word_list:
        x = x.lower()
        
        if x == y:
            words_eq.append(y)
        else:
            pass
    #print(len(words_eq))
    if len(words_eq) == 0:
        return True
    else:
        words_eq.clear()
        return False
    
    
    # your code here

# %%
word_filter("lolo")
# Out:
# True

# %% [markdown]
# Use the `filter()` function to filter out the words speficied in the `word_filter()` function. Store the filtered list in the variable `prophet_filter`.

# %%
print(prophet_flat)
prophet_filter = list(filter(word_filter,prophet_flat))
print(prophet_filter[0:100])
# Out:
# ['Gibran', '', 'This', 'and', 'most', 'restrictions', 'whatsoever.', 'terms', 'of', 'at', 'www.gutenberg.org.', "you'll", 'have', 'using', 'this', 'ebook.', '', '', '', 'Title:', 'Prophet', '', 'Author:', 'Gibran', '', 'Release', '#58585]', 'Last', '2018', '', '', 'Language:', 'English', '', 'Character', 'UTF-8', '', '***', '***', '', '', '', '', 'Produced', 'generously', 'provided', 'Archive', '', '', "Transcriber's", 'this', 'utf-8', 'unencumbered', 'with', '58585-8.txt.', '', '', '', '', '', '', '', 'THE', 'PROPHET', '', 'By', 'Gibran', '', 'New', 'Knopf', '', '1923', '', '_The', 'Volume', 'Are', 'By', 'The', 'Author_', '', '', '“His', 'reservoir', 'of', 'have', 'been', 'the', 'majesty', 'with', 'which', 'own?”', '', '--Claude', 'Bragdon', '', '', 'THE', 'GIBRAN', '', 'The', '1919', 'The', '1923', 'Sand', 'of', 'Man.', 'The', 'Wanderer.', 'Prophet', '1933', 'the', 'Valley.', '1948', '', '', '', '', 'CONTENTS', '', '', 'Ship.......7', '', 'Love.....................15', '', 'Marriag
# ...

# %% [markdown]
# # Bonus Challenge
#
# Rewrite the `word_filter` function above to not be case sensitive.

# %%
def word_filter_case(x):
   
    
            
        
    
    # your code here
# Out:
#   Cell In[17], line 7
#     # your code here
#                     ^
# SyntaxError: incomplete input

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 word_filter_case("the")
#
# Cell In[64], line 9, in word_filter_case(x)
#       6 x = x.lower()
#       8 if x == y:
# ----> 9     words_eq.append(y)
#      10 else:
#      11     pass
#
# NameError: name 'words_eq' is not defined

# %% [markdown]
# # Challenge 3 - Reducing
#
# #### Now that we have significantly cleaned up our text corpus, let's use the `reduce()` function to put the words back together into one long string separated by spaces.
#
# We will start by writing a function that takes two strings and concatenates them together with a space between the two strings.

# %%
def concat_space(a, b):
    '''
    Input:Two strings
    Output: A single string separated by a space
        
    Example:
    Input: 'John', 'Smith'
    Output: 'John Smith'
    '''

    reduced_string = a + " " +  b
    return reduced_string
    
    # your code here

# %%
concat_space("Hola,"," que tal")
# Out:
# 'Hola,  que tal'

# %% [markdown]
# Use the function above to reduce the text corpus in the list `prophet_filter` into a single string. Assign this new string to the variable `prophet_string`.

# %%
# your code here
prophet_string = ''
for x in prophet_filter:
    prophet_string = concat_space(prophet_string,x)

# %%
print(prophet_string)
# Out:
#  Gibran  This most restrictions whatsoever. terms of at www.gutenberg.org. you'll have using this ebook.    Title: Prophet  Author: Gibran  Release #58585] Last 2018   Language: English  Character UTF-8  *** ***     Produced generously provided Archive   Transcriber's this utf-8 unencumbered with 58585-8.txt.        PROPHET  By Gibran  New Knopf  1923  _The Volume Are By Author_   “His reservoir of have been majesty with which own?”  --Claude Bragdon   GIBRAN  1919 1923 Sand of Man. Wanderer. Prophet 1933 Valley. 1948     CONTENTS   Ship.......7  Love.....................15  Marriage.................19  Children.................21  Giving...................23  Drinking......27  Work.....................31  Sorrow...........33  Houses...................37  Clothes..................41  Selling.......43  Punishment.....45  Laws.....................51  Freedom..................55  Passion.......57  Pain.....................60  Self-Knowledge...........62  Teaching.................64  Fri
# ...

# %% [markdown]
# # Challenge 4 - Applying Functions to DataFrames
#
# #### Our next step is to use the apply function to a dataframe and transform all cells.
#
# To do this, we will connect to Ironhack's database and retrieve the data from the *pollution* database. Select the *beijing_pollution* table and retrieve its data.

# %%
# your code here
pollution = pd.read_csv(".\PRSA_data_2010.1.1-2014.12.31.csv")
pollution
# Out:
#           No  year  month  day  hour  pm2.5  DEWP  TEMP    PRES cbwd     Iws  \
# 0          1  2010      1    1     0    NaN   -21 -11.0  1021.0   NW    1.79
# 1          2  2010      1    1     1    NaN   -21 -12.0  1020.0   NW    4.92
# 2          3  2010      1    1     2    NaN   -21 -11.0  1019.0   NW    6.71
# 3          4  2010      1    1     3    NaN   -21 -14.0  1019.0   NW    9.84
# 4          5  2010      1    1     4    NaN   -20 -12.0  1018.0   NW   12.97
# ...      ...   ...    ...  ...   ...    ...   ...   ...     ...  ...     ...
# 43819  43820  2014     12   31    19    8.0   -23  -2.0  1034.0   NW  231.97
# 43820  43821  2014     12   31    20   10.0   -22  -3.0  1034.0   NW  237.78
# 43821  43822  2014     12   31    21   10.0   -22  -3.0  1034.0   NW  242.70
# 43822  43823  2014     12   31    22    8.0   -22  -4.0  1034.0   NW  246.72
# 43823  43824  2014     12   31    23   12.0   -21  -3.0  1034.0   NW  249.85
#
#        Is  Ir
# 0       0   0
# ...

# %% [markdown]
# Let's look at the data using the `head()` function.

# %%
# your code here
pollution.head()
# Out:
#    No  year  month  day  hour  pm2.5  DEWP  TEMP    PRES cbwd    Iws  Is  Ir
# 0   1  2010      1    1     0    NaN   -21 -11.0  1021.0   NW   1.79   0   0
# 1   2  2010      1    1     1    NaN   -21 -12.0  1020.0   NW   4.92   0   0
# 2   3  2010      1    1     2    NaN   -21 -11.0  1019.0   NW   6.71   0   0
# 3   4  2010      1    1     3    NaN   -21 -14.0  1019.0   NW   9.84   0   0
# 4   5  2010      1    1     4    NaN   -20 -12.0  1018.0   NW  12.97   0   0

# %% [markdown]
# The next step is to create a function that divides a cell by 24 to produce an hourly figure. Write the function below.

# %%
def hourly(x):
    '''
    Input: A numerical value
    Output: The value divided by 24
        
    Example:
    Input: 48
    Output: 2.0
    '''
    result = x / 24

    return result

    
    
    # your code here

# %% [markdown]
# Apply this function to the columns `Iws`, `Is`, and `Ir`. Store this new dataframe in the variable `pm25_hourly`.

# %%
# your code here
pollution["Iws"] = pollution["Iws"].apply(hourly)
pollution["Is"] = pollution["Is"].apply(hourly)
pollution["Ir"] = pollution["Ir"].apply(hourly)
pm25_hourly = pd.concat([pollution["Iws"],pollution["Is"],pollution["Ir"]],axis=1)
pm25_hourly
# Out:
#                 Iws   Is   Ir
# 0      9.366678e-09  0.0  0.0
# 1      2.574528e-08  0.0  0.0
# 2      3.511196e-08  0.0  0.0
# 3      5.149056e-08  0.0  0.0
# 4      6.786917e-08  0.0  0.0
# ...             ...  ...  ...
# 43819  1.213848e-06  0.0  0.0
# 43820  1.244251e-06  0.0  0.0
# 43821  1.269996e-06  0.0  0.0
# 43822  1.291032e-06  0.0  0.0
# 43823  1.307410e-06  0.0  0.0
#
# [43824 rows x 3 columns]

# %%
pm25_hourly.head()
# Out:
#             Iws   Is   Ir
# 0  9.366678e-09  0.0  0.0
# 1  2.574528e-08  0.0  0.0
# 2  3.511196e-08  0.0  0.0
# 3  5.149056e-08  0.0  0.0
# 4  6.786917e-08  0.0  0.0

# %% [markdown]
# #### Our last challenge will be to create an aggregate function and apply it to a select group of columns in our dataframe.
#
# Write a function that returns the standard deviation of a column divided by the length of a column minus 1. Since we are using pandas, do not use the `len()` function. One alternative is to use `count()`. Also, use the numpy version of standard deviation.

# %%
def sample_sd(x):
    '''
    Input: A Pandas series of values
    Output: the standard deviation divided by the number of elements in the series
        
    Example:
    Input: pd.Series([1,2,3,4])
    Output: 0.3726779962
    '''
    
    # your code here
