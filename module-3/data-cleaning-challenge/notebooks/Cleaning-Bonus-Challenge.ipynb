# %%
import pandas as pd
import numpy as np

# %%
data_url = "../iris-data.csv"
df1 = pd.read_csv(data_url)

# %%
df1
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0                5.1             3.5              1.4             0.2
# 1                4.9             3.0              1.4             0.2
# 2                4.7             3.2              1.3             0.2
# 3                4.6             3.1              1.5             0.2
# 4                5.0             3.6              1.4             0.2
# ..               ...             ...              ...             ...
# 145              6.7             3.0              5.2             2.3
# 146              6.3             2.5              5.0             2.3
# 147              6.5             3.0              5.2             2.0
# 148              6.2             3.4              5.4             2.3
# 149              5.9             3.0              5.1             1.8
#
#               class
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   sepal_length_cm  150 non-null    float64
#  1   sepal_width_cm   150 non-null    float64
#  2   petal_length_cm  150 non-null    float64
#  3   petal_width_cm   145 non-null    float64
#  4   class            150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df1["class"].unique()
# Out:
# array(['Iris-setosa', 'Iris-setossa', 'Iris-versicolor', 'versicolor',
#        'Iris-virginica'], dtype=object)

# %%
df_columns = ["sepal_length_cm", "sepal_width_cm", "petal_length_cm", "class"]

# %%
# Checking nulls in each column
for x in df_columns:
    nan_count = df1[x].isna().sum()
    print("Column " + x + " :")
    print(nan_count)
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# Cell In[25], line 3
#       1 # Checking nulls in each column
#       2 for x in df_columns:
# ----> 3     nan_count = df1[x].isna().sum().any(axis=1)
#       4     print("Column " + x + " :")
#       5     print(nan_count)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\_methods.py:58, in _any(a, axis, dtype, out, keepdims, where)
#      55 def _any(a, axis=None, dtype=None, out=None, keepdims=False, *, where=True):
#      56     # Parsing keyword arguments is currently fairly slow, so avoid it for now
#      57     if where is True:
# ---> 58         return umr_any(a, axis, dtype, out, keepdims)
#      59     return umr_any(a, axis, dtype, out, keepdims, where=where)
#
# AxisError: axis 1 is out of bounds for array of dimension 0

# %%
df1.head(25)
# Out:
#     sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0               5.1             3.5              1.4             0.2
# 1               4.9             3.0              1.4             0.2
# 2               4.7             3.2              1.3             0.2
# 3               4.6             3.1              1.5             0.2
# 4               5.0             3.6              1.4             0.2
# 5               5.4             3.9              1.7             0.4
# 6               4.6             3.4              1.4             0.3
# 7               5.0             3.4              1.5             NaN
# 8               4.4             2.9              1.4             NaN
# 9               4.9             3.1              1.5             NaN
# 10              5.4             3.7              1.5             NaN
# 11              4.8             3.4              1.6             NaN
# 12              4.8             3.0              1.4             0.1
# ...

# %%
df1.describe()
# Out:
#        sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm
# count       150.000000      150.000000       150.000000      145.000000
# mean          5.644627        3.054667         3.758667        1.236552
# std           1.312781        0.433123         1.764420        0.755058
# min           0.055000        2.000000         1.000000        0.100000
# 25%           5.100000        2.800000         1.600000        0.400000
# 50%           5.700000        3.000000         4.350000        1.300000
# 75%           6.400000        3.300000         5.100000        1.800000
# max           7.900000        4.400000         6.900000        2.500000

# %%
df1 = pd.get_dummies(df, columns=['class'], prefix='class')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df_encoded = pd.get_dummies(df, columns=['class'], prefix='class')
#
# NameError: name 'df' is not defined
