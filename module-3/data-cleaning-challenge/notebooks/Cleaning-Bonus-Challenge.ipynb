# %%
import pandas as pd
import numpy as np

# %%
data_url = "../iris-data.csv"
df1 = pd.read_csv(data_url)

# %%
df1
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0                5.1             3.5              1.4             0.2
# 1                4.9             3.0              1.4             0.2
# 2                4.7             3.2              1.3             0.2
# 3                4.6             3.1              1.5             0.2
# 4                5.0             3.6              1.4             0.2
# ..               ...             ...              ...             ...
# 145              6.7             3.0              5.2             2.3
# 146              6.3             2.5              5.0             2.3
# 147              6.5             3.0              5.2             2.0
# 148              6.2             3.4              5.4             2.3
# 149              5.9             3.0              5.1             1.8
#
#               class
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   sepal_length_cm  150 non-null    float64
#  1   sepal_width_cm   150 non-null    float64
#  2   petal_length_cm  150 non-null    float64
#  3   petal_width_cm   145 non-null    float64
#  4   class            150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df1["class"].unique()
# Out:
# array(['Iris-setosa', 'Iris-setossa', 'Iris-versicolor', 'versicolor',
#        'Iris-virginica'], dtype=object)

# %%
df_columns = ["sepal_length_cm", "sepal_width_cm", "petal_length_cm", "class"]

# %%
# Checking nulls in each column
for x in df_columns:
    nan_count = df1[x].isna().sum()
    print("Column " + x + " :")
    print(nan_count)
# Out:
# Column sepal_length_cm :
# 0
# Column sepal_width_cm :
# 0
# Column petal_length_cm :
# 0
# Column class :
# 0

# %%
df1.head(25)
# Out:
#     sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0               5.1             3.5              1.4             0.2
# 1               4.9             3.0              1.4             0.2
# 2               4.7             3.2              1.3             0.2
# 3               4.6             3.1              1.5             0.2
# 4               5.0             3.6              1.4             0.2
# 5               5.4             3.9              1.7             0.4
# 6               4.6             3.4              1.4             0.3
# 7               5.0             3.4              1.5             NaN
# 8               4.4             2.9              1.4             NaN
# 9               4.9             3.1              1.5             NaN
# 10              5.4             3.7              1.5             NaN
# 11              4.8             3.4              1.6             NaN
# 12              4.8             3.0              1.4             0.1
# ...

# %%
df1.describe()
# Out:
#        sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm
# count       150.000000      150.000000       150.000000      145.000000
# mean          5.644627        3.054667         3.758667        1.236552
# std           1.312781        0.433123         1.764420        0.755058
# min           0.055000        2.000000         1.000000        0.100000
# 25%           5.100000        2.800000         1.600000        0.400000
# 50%           5.700000        3.000000         4.350000        1.300000
# 75%           6.400000        3.300000         5.100000        1.800000
# max           7.900000        4.400000         6.900000        2.500000

# %%
df1 = pd.get_dummies(df1, columns=['class'], prefix='class')

# %%
df1
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0                5.1             3.5              1.4             0.2
# 1                4.9             3.0              1.4             0.2
# 2                4.7             3.2              1.3             0.2
# 3                4.6             3.1              1.5             0.2
# 4                5.0             3.6              1.4             0.2
# ..               ...             ...              ...             ...
# 145              6.7             3.0              5.2             2.3
# 146              6.3             2.5              5.0             2.3
# 147              6.5             3.0              5.2             2.0
# 148              6.2             3.4              5.4             2.3
# 149              5.9             3.0              5.1             1.8
#
#      class_Iris-setosa  class_Iris-setossa  class_Iris-versicolor  \
# ...

# %%
# Checking nulls
total_nulls = df1.isnull().sum()

# %%
print(total_nulls)
# Out:
# sepal_length_cm          0
# sepal_width_cm           0
# petal_length_cm          0
# petal_width_cm           5
# class_Iris-setosa        0
# class_Iris-setossa       0
# class_Iris-versicolor    0
# class_Iris-virginica     0
# class_versicolor         0
# dtype: int64

# %%
# Filling nulls with median
df1["petal_width_cm"] = df1["petal_width_cm"].fillna(df1["petal_width_cm"].median())

# %%
total_nulls = df1.isnull().sum()

# %%
# Checking if there are nulls
print(total_nulls)
# Out:
# sepal_length_cm          0
# sepal_width_cm           0
# petal_length_cm          0
# petal_width_cm           0
# class_Iris-setosa        0
# class_Iris-setossa       0
# class_Iris-versicolor    0
# class_Iris-virginica     0
# class_versicolor         0
# dtype: int64

# %%
# Checking the new value of the nulls
df1.head(25)
# Out:
#     sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0               5.1             3.5              1.4             0.2
# 1               4.9             3.0              1.4             0.2
# 2               4.7             3.2              1.3             0.2
# 3               4.6             3.1              1.5             0.2
# 4               5.0             3.6              1.4             0.2
# 5               5.4             3.9              1.7             0.4
# 6               4.6             3.4              1.4             0.3
# 7               5.0             3.4              1.5             1.3
# 8               4.4             2.9              1.4             1.3
# 9               4.9             3.1              1.5             1.3
# 10              5.4             3.7              1.5             1.3
# 11              4.8             3.4              1.6             1.3
# 12              4.8             3.0              1.4             0.1
# ...

# %%
df1 = df1.astype(int)

# %%
df1
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0                  5               3                1               0
# 1                  4               3                1               0
# 2                  4               3                1               0
# 3                  4               3                1               0
# 4                  5               3                1               0
# ..               ...             ...              ...             ...
# 145                6               3                5               2
# 146                6               2                5               2
# 147                6               3                5               2
# 148                6               3                5               2
# 149                5               3                5               1
#
#      class_Iris-setosa  class_Iris-setossa  class_Iris-versicolor  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   sepal_length_cm        150 non-null    int32
#  1   sepal_width_cm         150 non-null    int32
#  2   petal_length_cm        150 non-null    int32
#  3   petal_width_cm         150 non-null    int32
#  4   class_Iris-setosa      150 non-null    int32
#  5   class_Iris-setossa     150 non-null    int32
#  6   class_Iris-versicolor  150 non-null    int32
#  7   class_Iris-virginica   150 non-null    int32
#  8   class_versicolor       150 non-null    int32
# dtypes: int32(9)
# memory usage: 5.4 KB
